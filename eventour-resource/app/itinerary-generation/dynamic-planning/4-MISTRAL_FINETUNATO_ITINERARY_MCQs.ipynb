# %%
# Login to Hugging Face
HUGGINGFACE_TOKEN = ""
from huggingface_hub import login
login(token = HUGGINGFACE_TOKEN)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
pip install transformers accelerate bitsandbytes

# %% [markdown]
# MISTRAL-LABELLED

# %%
import pandas as pd
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch
import random

# Define model repo
MODEL_NAME = "matteanedda/Itinerary_Selection_Mistral"#"matteanedda/mistral-7b-instruct-logical-itinerary-selection-4bit-v5"

# POI Type Mapping
TYPE_MAPPING = {
    "Museo": "museum",
    "FermataDellaMetropolitana": "metro_station",
    "GalleriaDArte": "art_gallery",
    "Monumento": "monument",
    "Scultura": "sculpture",
    "Teatro": "theater"
}

def initialize_model():
    """Load the model with 4-bit quantization."""
    try:
        model = AutoModelForCausalLM.from_pretrained(
            MODEL_NAME,
            device_map="auto",
            trust_remote_code=True
        )
        tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
        return model, tokenizer
    except Exception as e:
        print(f"Error initializing model: {e}")
        exit()

def map_types_numeric(df):
    """Convert POI type names to numeric categories."""
    df["From_Type"] = df["From_Type"].map(TYPE_MAPPING).fillna(0)
    df["To_Type"] = df["To_Type"].map(TYPE_MAPPING).fillna(0)
    return df

def preprocess_pois_numeric(df, allowed_types=None):
    """
    Filter dataset based on max duration and allowed POI types.
    Always keeps 'FermataDellaMetropolitana' type POIs regardless of allowed_types.

    Parameters:
    df (DataFrame): Input dataframe with POI information
    max_duration (int): Maximum duration in seconds
    allowed_types (list): List of allowed POI types. If None or empty, all types are allowed.

    Returns:
    DataFrame: Filtered and processed dataframe
    """

    # Filter by allowed types if the list is not empty
    if allowed_types and len(allowed_types) > 0:
        # Always include FermataDellaMetropolitana
        if "FermataDellaMetropolitana" not in allowed_types:
            allowed_types = allowed_types + ["FermataDellaMetropolitana"]

        # Create masks for the filter conditions
        from_type_allowed = df['From_Type'].isin(allowed_types)
        to_type_allowed = df['To_Type'].isin(allowed_types)

        # Keep connections where both endpoints are in allowed types
        df = df[from_type_allowed & to_type_allowed]

    # Shuffle the dataframe
    df = df.sample(frac=1)
    df = df.reset_index(drop=True)

    return map_types_numeric(df)

def generate_prompt_numeric(filtered_df, interval, numb_itineraries, starting_poi, numb_pois_to_be_visited, additional_informations):
    """Generate a prompt for the model with enhanced bidirectionality explanation."""

    # Extract all valid metro POIs for final stops
    metro_pois = filtered_df[filtered_df["From_Type"] == "metro"]["From_Label"].unique()

    # Create a dictionary of valid connections for faster lookup
    valid_connections = {}
    for _, row in filtered_df.iterrows():
        from_key = (row['From_Label'], row['From_Type'])
        if from_key not in valid_connections:
            valid_connections[from_key] = []
        valid_connections[from_key].append({
            'to_label': row['To_Label'],
            'to_type': row['To_Type'],
            'time': round(row['Duration (s)'] / 60)
        })

    # Format the list of final stops
    final_stops_text = "\n".join([f"METRO: {label}" for label in metro_pois])

    # Generate transition text with numbered connections for easy reference
    transitions = []
    for i, (_, row) in enumerate(filtered_df.iterrows(), 1):
        # Check if either From_Type or To_Type is a metro_station
        is_metro_connection = row['From_Type'] == "metro_station" or row['To_Type'] == "metro_station"

        # Set the appropriate prefix
        prefix = "METRO CONNECTION: " if is_metro_connection else "REGULAR CONNECTION: "

        # Create the full transition string with the prefix
        transition = (
            f"{prefix}{row['From_Label']}, {row['From_Type']} - "
            f"{row['To_Label']}, {row['To_Type']} ----"
            f"WALKING TIME: {round(row['Duration (s)'] / 60)} min"
        )
        transitions.append(transition)

    transitions_text = "\n".join(transitions)

    prompt = f"""Generate {numb_itineraries} distinct walking itineraries by finding EXACT string matches.

The itineraries must visit {numb_pois_to_be_visited -1} cultural locations before arriving at a metro_station

[CRITICAL RULES]
- ONLY use connections where your Current Location appears EXACTLY (including type)
- Each itinerary must visit exactly {numb_pois_to_be_visited - 1} points before reaching metro_station
- You CANNOT use connections that don't contain your Current Location
- METRO CONNECTION must not appear in intermediate legs connections
- The itineraries should have a total time difference of around {interval} min.

[STEP BY STEP PROCESS]
For each step:

1. CURRENT LOCATION CHECK
Take your Current Location
Search the connections for the EXACT string
Search REGULAR CONNECTION
You can ONLY use connections where the EXACT string appears
Do not consider METRO CONNECTION

2. VERIFY CONNECTION
When you find a matching connection in the provided list:
- Copy the FULL connection string including walking time from the provided list
- Verify your Current Location appears exactly as one of the two locations
- Verify the walking time has been copied correctly
- Take the other location as your Next Location

3. CONTINUE PATH
- Your Next Location becomes your new Current Location
- Repeat the process
- Stop reaching a metro station at step {numb_pois_to_be_visited}

**IMPORTANT**
1. The connection for Leg 1 must contain {starting_poi} since the itinerary start from there. Otherwise it's invalid
2. Only the last leg (Leg {numb_pois_to_be_visited}) must be a METRO CONNECTION, all the other LEGs must not.
3. When you look for the connection containing a certain POI, check the full list. Do not suppose the connection.
4. When you select the connection to be used keep the walking time as well. Do not generate the time by yourself
5. Make sure the connection is the same as listed in the connection list
6. METRO CONNECTION must not be considered for the intermediate leg in each itinerary.
7. Leg 1 connection must be unique across all itineraries
8. Total Time must differ by around {interval} min across the {numb_itineraries} itineraries.

[OUTPUT FORMAT]
Itinerary #[N]:
Leg 1:
Current Location: {starting_poi}, type
Looking for REGULAR CONNECTION containing exactly: "{starting_poi}, type";
Found Connection: "[paste entire connection containing {starting_poi}]"
→ Next Location: [other location from connection, type]

Leg 2:
Current Location: [previous Next Location, type]
Looking for REGULAR CONNECTION containing exactly: "[previous Next Location, type]";
Found Connection: "[paste entire connection]"
→ Next Location: [other location from connection, type]

.....
Final Leg (Leg {numb_pois_to_be_visited}):
Current Location: [previous Next Location, type]
Looking for METRO CONNECTION containing exactly: "[previous Next Location]";
VERIFICATION: This connection DOES contain metro_station (REQUIRED)
Found Connection: "[paste entire connection]"
Final location: [metro_station]

Total Time: [time leg 1 + time leg 2 + ..... + time leg {numb_pois_to_be_visited}] = h min
------
Make sure to follow the logic for the previous location and next location.
Make sure to find the exact connection from the connection list and do not generate a connection by yourself
Make sure METRO CONNECTION DOES NOT APPEAR IN ANY INTERMEDIATE LEG
Make sure to use type METRO CONNECTION only as final leg (destination of the itinerary)
Make sure to retrive also the walking time from the connection list
Make sure to select different connection string for leg 1 across the different itineraries
Make sure to correctly sum the time of each leg as total time
Make sure Leg 1 connection is unique across all itineraries
Make sure to show the maths for the total time
Make sure to have {starting_poi} in the first Leg connection
------

[AVAILABLE CONNECTIONS]
All the existing connections are listed below:
{transitions_text}

Build exactly {numb_itineraries} itineraries with {numb_pois_to_be_visited} legs starting from {starting_poi}
[SOLUTION]
"""
    return prompt


def get_model_response(model, tokenizer, prompt, max_tokens=2000):
    """Generate a response from the model."""
    try:
        inputs = tokenizer(prompt, return_tensors="pt").to("cuda")
        outputs = model.generate(**inputs, max_new_tokens=max_tokens)
        return tokenizer.decode(outputs[0], skip_special_tokens=True)
    except Exception as e:
        print(f"Error calling model: {e}")
        return None

def display_response(response):
    """Print the formatted itinerary."""
    print("\n--- Generated Itineraries ---\n")
    print(response if response else "No valid response received.")

# %%
def main():
    interval = 8  # Allowed duration difference (minutes)
    numb_itineraries = 3  # Number of itineraries
    starting_poi = 'Museo del Novecento'  # Starting POI
    numb_pois_to_be_visited = 4
    additional_informations = '' #add additional infos as needed
    allowed_types = ['Monumento', 'Museo', 'GalleriaDArte']      #MUST BE: EMPTY, 'Teatro', 'Scultura', 'Monumento', 'GalleriaDArte', 'Museo'

    # Initialize the model
    model, tokenizer = initialize_model()

    # Load and preprocess the dataset
    df_path = r"/content/gdrive/MyDrive/BICOCCA/TESI/poi_distances_with_types_and_wikidata_POI_final_subset_20ina_POIs.csv"
    df = pd.read_csv(df_path)
    filtered_df = preprocess_pois_numeric(df, allowed_types)

    # Generate the prompt
    prompt = generate_prompt_numeric(filtered_df, interval, numb_itineraries, starting_poi, numb_pois_to_be_visited, additional_informations)

    # Get response
    itinerary_response = get_model_response(model, tokenizer, prompt)

    # Display itinerary
    display_response(itinerary_response)
    return itinerary_response

if __name__ == "__main__":
   response = main()
# Out:
# Unused kwargs: ['quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# --- Generated Itineraries ---
#
# Generate 3 distinct walking itineraries by finding EXACT string matches.
#
# The itineraries must visit 3 cultural locations before arriving at a metro_station
#
# [CRITICAL RULES]
# - ONLY use connections where your Current Location appears EXACTLY (including type)
# - Each itinerary must visit exactly 3 points before reaching metro_station
# - You CANNOT use connections that don't contain your Current Location
# - METRO CONNECTION must not appear in intermediate legs connections
# - The itineraries should have a total time difference of around 8 min.
#
# [STEP BY STEP PROCESS]
# For each step:
#
# 1. CURRENT LOCATION CHECK
# Take your Current Location
# Search the connections for the EXACT string
# Search REGULAR CONNECTION
# You can ONLY use connections where the EXACT string appears
# Do not consider METRO CONNECTION
#
# 2. VERIFY CONNECTION
# When you find a matching connection in the provided list:
# - Copy the FULL connection string including walking time from the provided list
# - Verify your Current Location appears exactly as one of the two locations
# - Verify the walking time has been copied correctly
# - Take the other location as your Next Location
#
# 3. CONTINUE PATH
# - Your Next Location becomes your new Current Location
# - Repeat the process
# - Stop reaching a metro station at step 4
#
# **IMPORTANT**
# 1. The connection for Leg 1 must contain Museo del Novecento since the itinerary start from there. Otherwise it's invalid
# 2. Only the last leg (Leg 4) must be a METRO CONNECTION, all the other LEGs must not.
# 3. When you look for the connection containing a certain POI, check the full list. Do not suppose the connection.
# 4. When you select the connection to be used keep the walking time as well. Do not generate the time by yourself
# 5. Make sure the connection is the same as listed in the connection list
# 6. METRO CONNECTION must not be considered for the intermediate leg in each itinerary.
# 7. Leg 1 connection must be unique across all itineraries
# 8. Total Time must differ by around 8 min across the 3 itineraries.
#
# [OUTPUT FORMAT]
# Itinerary #[N]:
# Leg 1:
# Current Location: Museo del Novecento, type
# Looking for REGULAR CONNECTION containing exactly: "Museo del Novecento, type";
# Found Connection: "[paste entire connection containing Museo del Novecento]"
# → Next Location: [other location from connection, type]
#
# Leg 2:
# Current Location: [previous Next Location, type]
# Looking for REGULAR CONNECTION containing exactly: "[previous Next Location, type]";
# Found Connection: "[paste entire connection]"
# → Next Location: [other location from connection, type]
#
# .....
# Final Leg (Leg 4):
# Current Location: [previous Next Location, type]
# Looking for METRO CONNECTION containing exactly: "[previous Next Location]";
# VERIFICATION: This connection DOES contain metro_station (REQUIRED)
# Found Connection: "[paste entire connection]"
# Final location: [metro_station]
#
# Total Time: [time leg 1 + time leg 2 + ..... + time leg 4] = h min
# ------
# Make sure to follow the logic for the previous location and next location.
# Make sure to find the exact connection from the connection list and do not generate a connection by yourself
# Make sure METRO CONNECTION DOES NOT APPEAR IN ANY INTERMEDIATE LEG
# Make sure to use type METRO CONNECTION only as final leg (destination of the itinerary)
# Make sure to retrive also the walking time from the connection list
# Make sure to select different connection string for leg 1 across the different itineraries
# Make sure to correctly sum the time of each leg as total time
# Make sure Leg 1 connection is unique across all itineraries
# Make sure to show the maths for the total time
# Make sure to have Museo del Novecento in the first Leg connection
# ------
#
# [AVAILABLE CONNECTIONS]
# All the existing connections are listed below:
# METRO CONNECTION: San Fedele museum, museum - Cordusio, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Museo Poldi Pezzoli, museum ----WALKING TIME: 14 min
# METRO CONNECTION: Duomo di Milano Museum, museum - Missori, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 5 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Monument to Cristina Trivulzio di Belgiojoso (Milan), monument ----WALKING TIME: 9 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Monument to Saint Ambrose, monument ----WALKING TIME: 3 min
# REGULAR CONNECTION: Duomo di Milano Museum, museum - San Fedele museum, museum ----WALKING TIME: 6 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Monument to Federico Borromeo, monument ----WALKING TIME: 2 min
# METRO CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Cordusio, metro_station ----WALKING TIME: 8 min
# REGULAR CONNECTION: Mario Buccellati corporate Museum, museum - Duomo di Milano Museum, museum ----WALKING TIME: 11 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Monument to Giuseppe Missori, monument ----WALKING TIME: 12 min
# METRO CONNECTION: Duomo, metro_station - San Babila, metro_station ----WALKING TIME: 8 min
# METRO CONNECTION: Collections of the Ospedale Maggiore, museum - Missori, metro_station ----WALKING TIME: 9 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 8 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 8 min
# METRO CONNECTION: Gallerie d'Italia - Milano, museum - Missori, metro_station ----WALKING TIME: 10 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Monument to Cristina Trivulzio di Belgiojoso (Milan), monument ----WALKING TIME: 9 min
# REGULAR CONNECTION: Monument to Federico Borromeo, monument - Monument to Giuseppe Missori, monument ----WALKING TIME: 5 min
# REGULAR CONNECTION: Mario Buccellati corporate Museum, museum - Gallerie d'Italia - Milano, museum ----WALKING TIME: 6 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Monument to Federico Borromeo, monument ----WALKING TIME: 11 min
# METRO CONNECTION: Gallerie d'Italia - Milano, museum - San Babila, metro_station ----WALKING TIME: 8 min
# REGULAR CONNECTION: Mario Buccellati corporate Museum, museum - Museo Poldi Pezzoli, museum ----WALKING TIME: 4 min
# REGULAR CONNECTION: Museo del Novecento, museum - Collections of the Ospedale Maggiore, museum ----WALKING TIME: 9 min
# METRO CONNECTION: Monument to Saint Ambrose, monument - Missori, metro_station ----WALKING TIME: 7 min
# METRO CONNECTION: San Fedele museum, museum - San Babila, metro_station ----WALKING TIME: 7 min
# METRO CONNECTION: Monument to Giuseppe Missori, monument - Cordusio, metro_station ----WALKING TIME: 7 min
# METRO CONNECTION: Monument to Federico Borromeo, monument - Missori, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - San Fedele museum, museum ----WALKING TIME: 11 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Monument to Giuseppe Missori, monument ----WALKING TIME: 5 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Collections of the Ospedale Maggiore, museum ----WALKING TIME: 13 min
# METRO CONNECTION: Duomo di Milano Museum, museum - Duomo, metro_station ----WALKING TIME: 5 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Museo Poldi Pezzoli, museum ----WALKING TIME: 3 min
# REGULAR CONNECTION: Monument to Giuseppe Missori, monument - San Fedele museum, museum ----WALKING TIME: 10 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Museo Mangini Bonomi, museum ----WALKING TIME: 7 min
# REGULAR CONNECTION: Monument to Federico Borromeo, monument - Duomo di Milano Museum, museum ----WALKING TIME: 8 min
# REGULAR CONNECTION: Mario Buccellati corporate Museum, museum - Monument to Saint Ambrose, monument ----WALKING TIME: 10 min
# REGULAR CONNECTION: Monument to Federico Borromeo, monument - San Fedele museum, museum ----WALKING TIME: 9 min
# METRO CONNECTION: Monument to Federico Borromeo, monument - San Babila, metro_station ----WALKING TIME: 15 min
# METRO CONNECTION: Mario Buccellati corporate Museum, museum - Duomo, metro_station ----WALKING TIME: 10 min
# REGULAR CONNECTION: Museo Poldi Pezzoli, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 10 min
# METRO CONNECTION: Mario Buccellati corporate Museum, museum - San Babila, metro_station ----WALKING TIME: 5 min
# METRO CONNECTION: Museo del Novecento, museum - San Babila, metro_station ----WALKING TIME: 10 min
# METRO CONNECTION: Duomo, metro_station - Missori, metro_station ----WALKING TIME: 7 min
# METRO CONNECTION: Leonardo3 Museum, museum - Cordusio, metro_station ----WALKING TIME: 4 min
# REGULAR CONNECTION: Monument to Saint Ambrose, monument - San Fedele museum, museum ----WALKING TIME: 5 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Royal Palace of Milan, museum ----WALKING TIME: 8 min
# METRO CONNECTION: Museo Poldi Pezzoli, museum - Duomo, metro_station ----WALKING TIME: 7 min
# REGULAR CONNECTION: Museo del Novecento, museum - Monument to Saint Ambrose, monument ----WALKING TIME: 4 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Monument to Cristina Trivulzio di Belgiojoso (Milan), monument ----WALKING TIME: 4 min
# METRO CONNECTION: San Fedele museum, museum - Missori, metro_station ----WALKING TIME: 10 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Monument to Saint Ambrose, monument ----WALKING TIME: 7 min
# REGULAR CONNECTION: Gallerie d'Italia - Milano, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 9 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 1 min
# METRO CONNECTION: Duomo di Milano Museum, museum - San Babila, metro_station ----WALKING TIME: 9 min
# REGULAR CONNECTION: Monument to Saint Ambrose, monument - Duomo di Milano Museum, museum ----WALKING TIME: 5 min
# METRO CONNECTION: Museo del Novecento, museum - Missori, metro_station ----WALKING TIME: 5 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Duomo di Milano Museum, museum ----WALKING TIME: 8 min
# REGULAR CONNECTION: Monument to Federico Borromeo, monument - Gallerie d'Italia - Milano, museum ----WALKING TIME: 8 min
# METRO CONNECTION: Cordusio, metro_station - San Babila, metro_station ----WALKING TIME: 12 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Gallerie d'Italia - Milano, museum ----WALKING TIME: 8 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - San Fedele museum, museum ----WALKING TIME: 8 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Mario Buccellati corporate Museum, museum ----WALKING TIME: 13 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 9 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Monument to Cristina Trivulzio di Belgiojoso (Milan), monument ----WALKING TIME: 12 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Royal Palace of Milan, museum ----WALKING TIME: 8 min
# METRO CONNECTION: Mario Buccellati corporate Museum, museum - Missori, metro_station ----WALKING TIME: 16 min
# REGULAR CONNECTION: Museo Poldi Pezzoli, museum - Duomo di Milano Museum, museum ----WALKING TIME: 10 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Gallerie d'Italia - Milano, museum ----WALKING TIME: 8 min
# METRO CONNECTION: Royal Palace of Milan, museum - San Babila, metro_station ----WALKING TIME: 9 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Gallerie d'Italia - Milano, museum ----WALKING TIME: 1 min
# METRO CONNECTION: Gallerie d'Italia - Milano, museum - Duomo, metro_station ----WALKING TIME: 5 min
# METRO CONNECTION: Gallerie d'Italia - Milano, museum - Cordusio, metro_station ----WALKING TIME: 5 min
# REGULAR CONNECTION: Museo del Novecento, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 6 min
# METRO CONNECTION: Missori, metro_station - Cordusio, metro_station ----WALKING TIME: 8 min
# REGULAR CONNECTION: Gallerie d'Italia - Milano, museum - San Fedele museum, museum ----WALKING TIME: 2 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Duomo di Milano Museum, museum ----WALKING TIME: 8 min
# METRO CONNECTION: Monument to Giuseppe Missori, monument - San Babila, metro_station ----WALKING TIME: 14 min
# METRO CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Missori, metro_station ----WALKING TIME: 12 min
# METRO CONNECTION: Leonardo3 Museum, museum - San Babila, metro_station ----WALKING TIME: 9 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Pinacoteca Ambrosiana, art_gallery ----WALKING TIME: 1 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Monument to Saint Ambrose, monument ----WALKING TIME: 13 min
# REGULAR CONNECTION: Museo del Novecento, museum - Monument to Cristina Trivulzio di Belgiojoso (Milan), monument ----WALKING TIME: 8 min
# METRO CONNECTION: Monument to Saint Ambrose, monument - San Babila, metro_station ----WALKING TIME: 10 min
# REGULAR CONNECTION: Monument to Saint Ambrose, monument - Gallerie d'Italia - Milano, museum ----WALKING TIME: 4 min
# REGULAR CONNECTION: Museo del Novecento, museum - Duomo di Milano Museum, museum ----WALKING TIME: 2 min
# METRO CONNECTION: Museo del Novecento, museum - Cordusio, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Gallerie d'Italia - Milano, museum ----WALKING TIME: 7 min
# REGULAR CONNECTION: Museo del Novecento, museum - Museo Poldi Pezzoli, museum ----WALKING TIME: 8 min
# REGULAR CONNECTION: Monument to Saint Ambrose, monument - Monument to Giuseppe Missori, monument ----WALKING TIME: 6 min
# METRO CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Duomo, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 14 min
# METRO CONNECTION: Collections of the Ospedale Maggiore, museum - San Babila, metro_station ----WALKING TIME: 11 min
# METRO CONNECTION: Royal Palace of Milan, museum - Duomo, metro_station ----WALKING TIME: 5 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Duomo di Milano Museum, museum ----WALKING TIME: 8 min
# METRO CONNECTION: Collections of the Ospedale Maggiore, museum - Duomo, metro_station ----WALKING TIME: 11 min
# REGULAR CONNECTION: Mario Buccellati corporate Museum, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 15 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Monument to Saint Ambrose, monument ----WALKING TIME: 4 min
# METRO CONNECTION: Pinacoteca Ambrosiana, art_gallery - Missori, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Collections of the Ospedale Maggiore, museum ----WALKING TIME: 15 min
# REGULAR CONNECTION: Museo del Novecento, museum - Gallerie d'Italia - Milano, museum ----WALKING TIME: 6 min
# METRO CONNECTION: Pinacoteca Ambrosiana, art_gallery - Duomo, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Gallerie d'Italia - Milano, museum ----WALKING TIME: 3 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Museo Poldi Pezzoli, museum ----WALKING TIME: 2 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - San Fedele museum, museum ----WALKING TIME: 2 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Monument to Cristina Trivulzio di Belgiojoso (Milan), monument ----WALKING TIME: 10 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - San Fedele museum, museum ----WALKING TIME: 7 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Monument to Saint Ambrose, monument ----WALKING TIME: 4 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Duomo di Milano Museum, museum ----WALKING TIME: 8 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Pinacoteca Ambrosiana, art_gallery ----WALKING TIME: 14 min
# REGULAR CONNECTION: Museo del Novecento, museum - Mario Buccellati corporate Museum, museum ----WALKING TIME: 12 min
# METRO CONNECTION: Museo Poldi Pezzoli, museum - San Babila, metro_station ----WALKING TIME: 8 min
# METRO CONNECTION: Royal Palace of Milan, museum - Cordusio, metro_station ----WALKING TIME: 7 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Duomo di Milano Museum, museum ----WALKING TIME: 1 min
# METRO CONNECTION: Collections of the Ospedale Maggiore, museum - Cordusio, metro_station ----WALKING TIME: 14 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Monument to Saint Ambrose, monument ----WALKING TIME: 6 min
# REGULAR CONNECTION: Museo del Novecento, museum - San Fedele museum, museum ----WALKING TIME: 6 min
# METRO CONNECTION: San Fedele museum, museum - Duomo, metro_station ----WALKING TIME: 4 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Museo Poldi Pezzoli, museum ----WALKING TIME: 10 min
# REGULAR CONNECTION: Monument to Giuseppe Missori, monument - Duomo di Milano Museum, museum ----WALKING TIME: 6 min
# METRO CONNECTION: Pinacoteca Ambrosiana, art_gallery - Cordusio, metro_station ----WALKING TIME: 3 min
# REGULAR CONNECTION: Museo del Novecento, museum - Royal Palace of Milan, museum ----WALKING TIME: 2 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - Mario Buccellati corporate Museum, museum ----WALKING TIME: 6 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Museo Poldi Pezzoli, museum ----WALKING TIME: 9 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 6 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Royal Palace of Milan, museum ----WALKING TIME: 8 min
# REGULAR CONNECTION: Museo del Novecento, museum - Leonardo3 Museum, museum ----WALKING TIME: 6 min
# METRO CONNECTION: Monument to Federico Borromeo, monument - Duomo, metro_station ----WALKING TIME: 7 min
# METRO CONNECTION: Monument to Giuseppe Missori, monument - Missori, metro_station ----WALKING TIME: 1 min
# METRO CONNECTION: Monument to Saint Ambrose, monument - Duomo, metro_station ----WALKING TIME: 3 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Mario Buccellati corporate Museum, museum ----WALKING TIME: 7 min
# METRO CONNECTION: Royal Palace of Milan, museum - Missori, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Museo Poldi Pezzoli, museum - Monument to Saint Ambrose, monument ----WALKING TIME: 6 min
# METRO CONNECTION: Monument to Giuseppe Missori, monument - Duomo, metro_station ----WALKING TIME: 7 min
# REGULAR CONNECTION: Gallerie d'Italia - Milano, museum - Duomo di Milano Museum, museum ----WALKING TIME: 8 min
# METRO CONNECTION: Museo Poldi Pezzoli, museum - Cordusio, metro_station ----WALKING TIME: 7 min
# REGULAR CONNECTION: Museo del Novecento, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 5 min
# REGULAR CONNECTION: Museo del Novecento, museum - Museo Mangini Bonomi, museum ----WALKING TIME: 6 min
# REGULAR CONNECTION: Museo Poldi Pezzoli, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 11 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Mario Buccellati corporate Museum, museum ----WALKING TIME: 14 min
# METRO CONNECTION: Missori, metro_station - San Babila, metro_station ----WALKING TIME: 14 min
# REGULAR CONNECTION: Royal Palace of Milan, museum - Mario Buccellati corporate Museum, museum ----WALKING TIME: 12 min
# METRO CONNECTION: Museo Mangini Bonomi, museum - Cordusio, metro_station ----WALKING TIME: 4 min
# METRO CONNECTION: Museo Mangini Bonomi, museum - Duomo, metro_station ----WALKING TIME: 7 min
# REGULAR CONNECTION: Mario Buccellati corporate Museum, museum - San Fedele museum, museum ----WALKING TIME: 7 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Duomo di Milano Museum, museum ----WALKING TIME: 7 min
# METRO CONNECTION: Museo Poldi Pezzoli, museum - Missori, metro_station ----WALKING TIME: 12 min
# METRO CONNECTION: Mario Buccellati corporate Museum, museum - Cordusio, metro_station ----WALKING TIME: 11 min
# METRO CONNECTION: Leonardo3 Museum, museum - Duomo, metro_station ----WALKING TIME: 5 min
# REGULAR CONNECTION: Museo Mangini Bonomi, museum - Museo Poldi Pezzoli, museum ----WALKING TIME: 10 min
# REGULAR CONNECTION: Monument to Federico Borromeo, monument - Monument to Saint Ambrose, monument ----WALKING TIME: 5 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Gallerie d'Italia - Milano, museum ----WALKING TIME: 13 min
# REGULAR CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - San Fedele museum, museum ----WALKING TIME: 2 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - Royal Palace of Milan, museum ----WALKING TIME: 7 min
# REGULAR CONNECTION: Leonardo3 Museum, museum - Pinacoteca Ambrosiana, art_gallery ----WALKING TIME: 6 min
# METRO CONNECTION: Duomo di Milano Museum, museum - Cordusio, metro_station ----WALKING TIME: 7 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Mario Buccellati corporate Museum, museum ----WALKING TIME: 15 min
# REGULAR CONNECTION: Museo del Novecento, museum - Pinacoteca Ambrosiana, art_gallery ----WALKING TIME: 5 min
# METRO CONNECTION: Museo del Novecento, museum - Duomo, metro_station ----WALKING TIME: 3 min
# METRO CONNECTION: Monument to Federico Borromeo, monument - Cordusio, metro_station ----WALKING TIME: 5 min
# REGULAR CONNECTION: Collections of the Ospedale Maggiore, museum - Monument to Giuseppe Missori, monument ----WALKING TIME: 10 min
# METRO CONNECTION: Leonardo3 Museum, museum - Missori, metro_station ----WALKING TIME: 10 min
# METRO CONNECTION: Monument to Saint Ambrose, monument - Cordusio, metro_station ----WALKING TIME: 2 min
# REGULAR CONNECTION: Museo Poldi Pezzoli, museum - Gallerie d'Italia - Milano, museum ----WALKING TIME: 2 min
# METRO CONNECTION: Museo Mangini Bonomi, museum - San Babila, metro_station ----WALKING TIME: 14 min
# METRO CONNECTION: Monument to Cristina Trivulzio di Belgiojoso (Milan), monument - San Babila, metro_station ----WALKING TIME: 6 min
# METRO CONNECTION: Pinacoteca Ambrosiana, art_gallery - San Babila, metro_station ----WALKING TIME: 13 min
# METRO CONNECTION: Duomo, metro_station - Cordusio, metro_station ----WALKING TIME: 4 min
# REGULAR CONNECTION: Pinacoteca Ambrosiana, art_gallery - San Fedele museum, museum ----WALKING TIME: 7 min
# METRO CONNECTION: Museo Mangini Bonomi, museum - Missori, metro_station ----WALKING TIME: 6 min
# REGULAR CONNECTION: Museo Poldi Pezzoli, museum - San Fedele museum, museum ----WALKING TIME: 4 min
# REGULAR CONNECTION: Mario Buccellati corporate Museum, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 14 min
#
# Build exactly 3 itineraries with 4 legs starting from Museo del Novecento
# [SOLUTION]
# Itinerary #1:
# Leg 1:
# Current Location: Museo del Novecento, museum
# Looking for REGULAR CONNECTION containing exactly: "Museo del Novecento, museum";
# Found Connection: "Museo del Novecento, museum - Collections of the Ospedale Maggiore, museum ----WALKING TIME: 9 min"
# → Next Location: Collections of the Ospedale Maggiore, museum
#
# Leg 2:
# Current Location: Collections of the Ospedale Maggiore, museum
# Looking for REGULAR CONNECTION containing exactly: "Collections of the Ospedale Maggiore, museum";
# Found Connection: "Collections of the Ospedale Maggiore, museum - Duomo di Milano Museum, museum ----WALKING TIME: 8 min"
# → Next Location: Duomo di Milano Museum, museum
#
# Leg 3:
# Current Location: Duomo di Milano Museum, museum
# Looking for REGULAR CONNECTION containing exactly: "Duomo di Milano Museum, museum";
# Found Connection: "Duomo di Milano Museum, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 8 min"
# → Next Location: Monument to Federico Borromeo, monument
#
# Leg 4:
# Current Location: Monument to Federico Borromeo, monument
# Looking for METRO CONNECTION containing exactly: "Monument to Federico Borromeo, monument";
# VERIFICATION: This connection DOES contain metro_station (REQUIRED)
# Found Connection: "Monument to Federico Borromeo, monument - Missori, metro_station ----WALKING TIME: 6 min"
# Final location: Missori, metro_station
#
# Total Time: 9 min + 8 min + 8 min + 6 min = 31 min
#
# Itinerary #2:
# Leg 1:
# Current Location: Museo del Novecento, museum
# Looking for REGULAR CONNECTION containing exactly: "Museo del Novecento, museum";
# Found Connection: "Museo del Novecento, museum - Pinacoteca Ambrosiana, art_gallery ----WALKING TIME: 5 min"
# → Next Location: Pinacoteca Ambrosiana, art_gallery
#
# Leg 2:
# Current Location: Pinacoteca Ambrosiana, art_gallery
# Looking for REGULAR CONNECTION containing exactly: "Pinacoteca Ambrosiana, art_gallery";
# Found Connection: "Pinacoteca Ambrosiana, art_gallery - Monument to Giuseppe Missori, monument ----WALKING TIME: 5 min"
# → Next Location: Monument to Giuseppe Missori, monument
#
# Leg 3:
# Current Location: Monument to Giuseppe Missori, monument
# Looking for REGULAR CONNECTION containing exactly: "Monument to Giuseppe Missori, monument";
# Found Connection: "Monument to Giuseppe Missori, monument - San Fedele museum, museum ----WALKING TIME: 10 min"
# → Next Location: San Fedele museum, museum
#
# Leg 4:
# Current Location: San Fedele museum, museum
# Looking for METRO CONNECTION containing exactly: "San Fedele museum, museum";
# Found Connection: "San Fedele museum, museum - San Babila, metro_station ----WALKING TIME: 7 min"
# Final location: San Babila, metro_station
#
# Total Time: 5 min + 5 min + 10 min + 7 min = 27 min
#
# Itinerary #3:
# Leg 1:
# Current Location: Museo del Novecento, museum
# Looking for REGULAR CONNECTION containing exactly: "Museo del Novecento, museum";
# Found Connection: "Museo del Novecento, museum - Royal Palace of Milan, museum ----WALKING TIME: 2 min"
# → Next Location: Royal Palace of Milan, museum
#
# Leg 2:
# Current Location: Royal Palace of Milan, museum
# Looking for REGULAR CONNECTION containing exactly: "Royal Palace of Milan, museum";
# Found Connection: "Royal Palace of Milan, museum - Monument to Federico Borromeo, monument ----WALKING TIME: 8 min"
# → Next Location: Monument to Federico Borromeo, monument
#
# Leg 3:
# Current Location: Monument to Federico Borromeo, monument
# Looking for REGULAR CONNECTION containing exactly: "Monument to Federico Borromeo, monument";
# Found Connection: "Monument to Federico Borromeo, monument - Gallerie d'Italia - Milano, museum ----WALKING TIME: 8 min"
# → Next Location: Gallerie d'Italia - Milano, museum
#
# Leg 4:
# Current Location: Gallerie d'Italia - Milano, museum
# Looking for METRO CONNECTION containing exactly: "Gallerie d'Italia - Milano, museum";
# Found Connection: "Gallerie d'Italia - Milano, museum - San Babila, metro_station ----WALKING TIME: 8 min"
# Final location: San Babila, metro_station
#
# Total Time: 2 min + 8 min + 8 min + 8 min = 26 min

# %% [markdown]
# LLM DOMANDE

# %%
import pandas as pd
import re

def parse_itineraries(text):
    # Initialize lists to store data
    data = []

    # First get only the part after [SOLUTION]
    if '[SOLUTION]' in text:
        text = text.split('[SOLUTION]')[1]

    # Split the text by "Itinerary #" keyword to get individual itineraries
    itinerary_blocks = re.split(r'Itinerary #(\d+):', text)

    # Skip the first element which is just text before the first itinerary
    if len(itinerary_blocks) > 1:
        itinerary_blocks = itinerary_blocks[1:]

    # Process each itinerary (number and content alternating)
    for i in range(0, len(itinerary_blocks), 2):
        if i + 1 >= len(itinerary_blocks):
            break

        try:
            # Clean up and convert itinerary number
            itinerary_num = int(itinerary_blocks[i].strip())
            itinerary_text = itinerary_blocks[i + 1]

            # Extract legs
            legs = re.findall(r'Leg \d+:.*?(?=Leg \d+:|Final Leg \(Leg \d+\):|Total Time:|$)', itinerary_text, re.DOTALL)
            final_leg = re.findall(r'Final Leg \(Leg \d+\):.*?(?=Total Time:|$)', itinerary_text, re.DOTALL)

            # Combine regular legs and final leg if it exists
            if final_leg:
                legs.extend(final_leg)

            # Process each leg
            for leg_index, leg in enumerate(legs):
                # Extract current location
                current_location_match = re.search(r'Current Location: (.*?), (.*?)(?=Looking|\n)', leg, re.DOTALL)
                if current_location_match:
                    poi_name, poi_type = current_location_match.groups()
                    poi_name = poi_name.strip()
                    poi_type = poi_type.strip()

                    # Only add as start if it's the first leg
                    if leg_index == 0:
                        data.append({
                            'Itinerary': itinerary_num,
                            'Poi_name': poi_name,
                            'role': 'Start',
                            'type': poi_type,
                            'walking_time': 0  # Starting point has 0 walking time
                        })

                # Extract walking time
                walking_time_match = re.search(r'WALKING TIME: (\d+) min', leg, re.DOTALL)
                walking_time = 0
                if walking_time_match:
                    walking_time = int(walking_time_match.group(1))

                # Extract next location
                next_location_match = re.search(r'→ Next Location: (.*?), (.*?)(?=\n|$)', leg, re.DOTALL)
                if next_location_match:
                    poi_name, poi_type = next_location_match.groups()
                    poi_name = poi_name.strip()
                    poi_type = poi_type.strip()
                    data.append({
                        'Itinerary': itinerary_num,
                        'Poi_name': poi_name,
                        'role': f'Stop{leg_index + 1}',
                        'type': poi_type,
                        'walking_time': walking_time
                    })

            # Process the final location (only if present)
            final_match = re.search(r'Final location: (.*?), (.*?)(?=\n|$)', itinerary_text, re.DOTALL)
            if final_match:
                poi_name, poi_type = final_match.groups()
                poi_name = poi_name.strip()
                poi_type = poi_type.strip()

                # Extract walking time from the final leg
                final_walking_time = 0
                if legs and len(legs) > 0:
                    final_walking_time_match = re.search(r'WALKING TIME: (\d+) min', legs[-1], re.DOTALL)
                    if final_walking_time_match:
                        final_walking_time = int(final_walking_time_match.group(1))

                # Check if this is already added
                if data and data[-1]['Itinerary'] == itinerary_num:
                    last_entry = data[-1]
                    if not (last_entry['Poi_name'] == poi_name and last_entry['type'] == poi_type):
                        data.append({
                            'Itinerary': itinerary_num,
                            'Poi_name': poi_name,
                            'role': f'Stop{len(legs)}',
                            'type': poi_type,
                            'walking_time': final_walking_time
                        })
                else:
                    data.append({
                        'Itinerary': itinerary_num,
                        'Poi_name': poi_name,
                        'role': f'Stop{len(legs)}',
                        'type': poi_type,
                        'walking_time': final_walking_time
                    })

        except (ValueError, IndexError) as e:
            print(f"Error processing itinerary: {e}")
            continue

    # Create DataFrame
    df = pd.DataFrame(data)
    return df

# %%
df = parse_itineraries(response)
df
# Out:
#     Itinerary                              Poi_name   role           type  \
# 0           1                   Museo del Novecento  Start         museum
# 1           1  Collections of the Ospedale Maggiore  Stop1         museum
# 2           1                Duomo di Milano Museum  Stop2         museum
# 3           1         Monument to Federico Borromeo  Stop3       monument
# 4           1                               Missori  Stop4  metro_station
# 5           2                   Museo del Novecento  Start         museum
# 6           2                 Pinacoteca Ambrosiana  Stop1    art_gallery
# 7           2          Monument to Giuseppe Missori  Stop2       monument
# 8           2                     San Fedele museum  Stop3         museum
# 9           2                            San Babila  Stop4  metro_station
# 10          3                   Museo del Novecento  Start         museum
# 11          3                 Royal Palace of Milan  Stop1         museum
# 12          3         Monument to Federico Borromeo  Stop2       monument
# 13          3            Gallerie d'Italia - Milano  Stop3         museum
# 14          3                            San Babila  Stop4  metro_station
#
#     walking_time
# 0              0
# 1              9
# 2              8
# 3              8
# 4              6
# 5              0
# 6              5
# 7              5
# 8             10
# 9              7
# 10             0
# 11             2
# 12             8
# 13             8
# 14             8

# %%
path_wikidata = r"/content/gdrive/MyDrive/BICOCCA/TESI/pois_with_wikidata.csv"
df_wikidata = pd.read_csv(path_wikidata)

# %%
df_wikidata
# Out:
#     Unnamed: 0.1  Unnamed: 0     POI                       TYPE  \
# 0              0           0  106481                   Scultura
# 1              1           1  108187                      Museo
# 2              2           2  115154                   Scultura
# 3              3           3  119513                      Museo
# 4              4           4  108242                      Museo
# 5              5           5   98652                      Museo
# 6              6           6  109486              GalleriaDArte
# 7              7           7  107078                      Museo
# 8              8           8  120148                  Monumento
# 9              9           9  110593                     Teatro
# 10            11          11  125115                      Museo
# 11            12          12  104275                   Scultura
# 12            13          13  102611                     Teatro
# 13            14          15  123910                   Scultura
# 14            15          16  110823                   Scultura
# 15            16          17  117876                     Teatro
# 16            17          18  123389                      Museo
# 17            18          19  114021                     Teatro
# 18            19          20  107439                  Monumento
# 19            20          21  113977                  Monumento
# 20            21          23  115460                   Scultura
# 21            22          24  119536                      Museo
# 22            25          28  101859                  Monumento
# 23            26          29  119864                     Teatro
# 24            27          30  122600                   Scultura
# 25            28          31  107607                      Museo
# 26            29          33  116866                     Teatro
# 27            30          34  117761                      Museo
# 28            32          36  118340                     Teatro
# 29            10          10  112602  FermataDellaMetropolitana
# 30            23          25  100111  FermataDellaMetropolitana
# 31            24          27  115437  FermataDellaMetropolitana
# 32            31          35  118236  FermataDellaMetropolitana
#
#                                PLACE    WIKIDATA   LATITUDE  LONGITUDE  \
# 0                   via-san-maurilio   Q56604977  45.462840   9.182910
# 1              via-guglielmo-marconi     Q261233  45.463414   9.190261
# 2                    piazza-cordusio   Q63633198  45.465456   9.186394
# 3                 piazza-della-scala   Q55832575  45.467339   9.189588
# 4                via-dell-ambrosiana   Q55376499  45.463430   9.185222
# 5   universita-degli-studi-di-milano   Q17154436  45.460009   9.195317
# 6                      piazza-pio-xi    Q1085811  45.463780   9.185952
# 7          cortile-del-palazzo-reale      Q51105  45.463054   9.191153
# 8                  piazza-belgioioso  Q109768623  45.467622   9.192375
# 9             piazza-cesare-beccaria   Q30880124  45.464135   9.194584
# 10               via-monte-napoleone   Q55670990  45.469086   9.194215
# 11              piazza-santo-stefano   Q63826242  45.462080   9.194850
# 12                         via-larga   Q71543196  45.461360   9.191700
# 13            via-alessandro-manzoni   Q56604893  45.468664   9.191583
# 14            piazza-cesare-beccaria   Q32107918  45.464210   9.194820
# 15                 piazza-san-babila    Q3982080  45.466490   9.197110
# 16                    la-feltrinelli    Q1190657  45.468484   9.191444
# 17                via-silvio-pellico    Q3982109  45.465100   9.189330
# 18       cardinale-federico-borromeo  Q115868258  45.463196   9.185228
# 19         palazzo-dei-giureconsulti  Q125794496  45.465083   9.188056
# 20        corso-vittorio-emanuele-ii    Q1094212  45.465564   9.195659
# 21            via-alessandro-manzoni    Q2054135  45.467350   9.190040
# 22           piazza-giuseppe-missori   Q21141701  45.461100   9.188100
# 23                via-filodrammatici    Q3982263  45.467503   9.188286
# 24                     via-romagnosi   Q56604939  45.468238   9.190992
# 25                     palazzo-reale   Q16337697  45.463246   9.191625
# 26                via-tommaso-marino   Q62588146  45.466070   9.190690
# 27      statua-di-alessandro-manzoni   Q24940273  45.466442   9.191131
# 28                       via-rovello   Q56477172  45.466719   9.184713
# 29                   via-ugo-foscolo    Q2519375  45.464722   9.190278
# 30           piazza-giuseppe-missori    Q1088817  45.460556   9.188333
# 31                   piazza-cordusio    Q1087020  45.465556   9.186389
# 32                 piazza-san-babila    Q1087622  45.466667   9.197500
#
#     DISTANCE wikidata_id                                              label
# 0   0.583524   Q56604977                                Grande bassorilievo
# 1   0.094433     Q261233                                Museo del Novecento
# 2   0.319298   Q63633198                        Monument to Giuseppe Parini
# 3   0.345171   Q55832575                                   Leonardo3 Museum
# 4   0.392464   Q55376499                               Museo Mangini Bonomi
# 5   0.622704   Q17154436               Collections of the Ospedale Maggiore
# 6   0.328911    Q1085811                              Pinacoteca Ambrosiana
# 7   0.156383      Q51105                              Royal Palace of Milan
# 8   0.413647  Q109768623  Monument to Cristina Trivulzio di Belgiojoso (...
# 9   0.348843   Q30880124                                    Teatro Gerolamo
# 10  0.624972   Q55670990                  Mario Buccellati corporate Museum
# 11  0.441592   Q63826242                   Monument to Varalli and Zibecchi
# 12  0.345054   Q71543196                     Teatro "La piccola Canobbiana"
# 13  0.503243   Q56604893                                        Sala d'armi
# 14  0.367021   Q32107918                        Monument to Cesare Beccaria
# 15  0.599437    Q3982080                                       Teatro Nuovo
# 16  0.481324    Q1190657                                Museo Poldi Pezzoli
# 17  0.111928    Q3982109                                          Teatro Re
# 18  0.398922  Q115868258                      Monument to Federico Borromeo
# 19  0.184987  Q125794496                          Monument to Saint Ambrose
# 20  0.456176    Q1094212                                       Scior Carera
# 21  0.343975    Q2054135                         Gallerie d'Italia - Milano
# 22  0.384590   Q21141701                       Monument to Giuseppe Missori
# 23  0.388079    Q3982263                              Teatro Filodrammatici
# 24  0.447940   Q56604939                 Disco in forma di rosa del deserto
# 25  0.162845   Q16337697                             Duomo di Milano Museum
# 26  0.206535   Q62588146                                     Teatro Manzoni
# 27  0.255525   Q24940273                                  San Fedele museum
# 28  0.502368   Q56477172                              Piccolo Teatro Grassi
# 29  0.053278    Q2519375                                              Duomo
# 30  0.434348    Q1088817                                            Missori
# 31  0.324448    Q1087020                                           Cordusio
# 32  0.635265    Q1087622                                         San Babila

# %%
# Merge on From_Label
df_merged = df.merge(df_wikidata[['label','LATITUDE', 'LONGITUDE','WIKIDATA']],
                       left_on='Poi_name', right_on='label',
                       how='left')

# %%
df_merged
# Out:
#     Itinerary                              Poi_name   role           type  \
# 0           1                   Museo del Novecento  Start         museum
# 1           1  Collections of the Ospedale Maggiore  Stop1         museum
# 2           1                Duomo di Milano Museum  Stop2         museum
# 3           1         Monument to Federico Borromeo  Stop3       monument
# 4           1                               Missori  Stop4  metro_station
# 5           2                   Museo del Novecento  Start         museum
# 6           2                 Pinacoteca Ambrosiana  Stop1    art_gallery
# 7           2          Monument to Giuseppe Missori  Stop2       monument
# 8           2                     San Fedele museum  Stop3         museum
# 9           2                            San Babila  Stop4  metro_station
# 10          3                   Museo del Novecento  Start         museum
# 11          3                 Royal Palace of Milan  Stop1         museum
# 12          3         Monument to Federico Borromeo  Stop2       monument
# 13          3            Gallerie d'Italia - Milano  Stop3         museum
# 14          3                            San Babila  Stop4  metro_station
#
#     walking_time                                 label   LATITUDE  LONGITUDE  \
# 0              0                   Museo del Novecento  45.463414   9.190261
# 1              9  Collections of the Ospedale Maggiore  45.460009   9.195317
# 2              8                Duomo di Milano Museum  45.463246   9.191625
# 3              8         Monument to Federico Borromeo  45.463196   9.185228
# 4              6                               Missori  45.460556   9.188333
# 5              0                   Museo del Novecento  45.463414   9.190261
# 6              5                 Pinacoteca Ambrosiana  45.463780   9.185952
# 7              5          Monument to Giuseppe Missori  45.461100   9.188100
# 8             10                     San Fedele museum  45.466442   9.191131
# 9              7                            San Babila  45.466667   9.197500
# 10             0                   Museo del Novecento  45.463414   9.190261
# 11             2                 Royal Palace of Milan  45.463054   9.191153
# 12             8         Monument to Federico Borromeo  45.463196   9.185228
# 13             8            Gallerie d'Italia - Milano  45.467350   9.190040
# 14             8                            San Babila  45.466667   9.197500
#
#       WIKIDATA
# 0      Q261233
# 1    Q17154436
# 2    Q16337697
# 3   Q115868258
# 4     Q1088817
# 5      Q261233
# 6     Q1085811
# 7    Q21141701
# 8    Q24940273
# 9     Q1087622
# 10     Q261233
# 11      Q51105
# 12  Q115868258
# 13    Q2054135
# 14    Q1087622

# %%
pip install SPARQLWrapper
# Out:
# Collecting SPARQLWrapper
#   Downloading SPARQLWrapper-2.0.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting rdflib>=6.1.1 (from SPARQLWrapper)
#   Downloading rdflib-7.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pyparsing<4,>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from rdflib>=6.1.1->SPARQLWrapper) (3.2.1)
# Downloading SPARQLWrapper-2.0.0-py3-none-any.whl (28 kB)
# Downloading rdflib-7.1.3-py3-none-any.whl (564 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.9/564.9 kB 17.2 MB/s eta 0:00:00
# Installing collected packages: rdflib, SPARQLWrapper
# Successfully installed SPARQLWrapper-2.0.0 rdflib-7.1.3

# %%
import pandas as pd
import sys
from SPARQLWrapper import SPARQLWrapper, JSON
import re

# SPARQL endpoint
endpoint_url = "https://query.wikidata.org/sparql"

# SPARQL query template
query_template = """
SELECT ?rdfsLabel ?instanceOfLabel ?materialLabel ?heritageStatusLabel
       # ?startime ?startime_2 ?creatorLabel ?description
WHERE {{
  wd:{entity_id} rdfs:label ?rdfsLabel.
  OPTIONAL {{ wd:{entity_id} wdt:P31 ?instanceOf. }}
  OPTIONAL {{ wd:{entity_id} wdt:P186 ?material. }}
  OPTIONAL {{ wd:{entity_id} wdt:P1435 ?heritageStatus. }}
  OPTIONAL {{ wd:{entity_id} wdt:P580 ?startime. }}
  OPTIONAL {{ wd:{entity_id} wdt:P571 ?startime_2. }}
  OPTIONAL {{ wd:{entity_id} wdt:P170 ?creator. }}
  OPTIONAL {{ wd:{entity_id} schema:description ?description. FILTER(LANG(?description) = "en") }}

  FILTER(LANG(?rdfsLabel) = "en")

  SERVICE wikibase:label {{
    bd:serviceParam wikibase:language "en".
    # ?instanceOf rdfs:label ?instanceOfLabel.
    # ?material rdfs:label ?materialLabel.
    # ?heritageStatus rdfs:label ?heritageStatusLabel.
    # ?creator rdfs:label ?creatorLabel.
  }}
}}
"""


def get_results(endpoint_url, query):
    """Fetch results from the SPARQL endpoint."""
    user_agent = f"WDQS-example Python/{sys.version_info[0]}.{sys.version_info[1]}"
    sparql = SPARQLWrapper(endpoint_url, agent=user_agent)
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)
    return sparql.query().convert()

def extract_qid(wikidata_url):
    """Extract Wikidata QID from URL."""
    if pd.isna(wikidata_url):
        return None
    match = re.search(r'Q\d+', str(wikidata_url))
    return match.group(0) if match else None

# Assuming your DataFrame is called 'data' and has a 'WIKIDATA' column
data = df_merged

# Add new columns for rdfs:label, instance of, material, and heritage status
data['label_'] = None
data["Instance_of"] = None
data["Material"] = None
data["Heritage_Status"] = None
data["Since"] = None
data["Since_2"] = None
data["Created_by"] = None
data["Description"] = None

# Iterate over each row in the dataset and query Wikidata
for index, row in data.iterrows():
    wikidata_url = row["WIKIDATA"]
    entity_id = extract_qid(wikidata_url)

    if entity_id is None:
        continue

    try:
        query = query_template.format(entity_id=entity_id)
        results = get_results(endpoint_url, query)

        # Initialize temporary variables for the query results
        label = None
        instance_of_label = None
        material_label = None
        heritage_status_label = None
        since_when = None
        since_when_2 = None
        creator = None
        description = None

        # Parse the results
        for result in results["results"]["bindings"]:
            if "rdfsLabel" in result:
                label = result["rdfsLabel"]["value"]

            # Extract wdt:P31 (instance of)
            if "instanceOfLabel" in result:
                instance_of_label = result["instanceOfLabel"]["value"]

            # Extract wdt:P186 (material)
            if "materialLabel" in result:
                material_label = result["materialLabel"]["value"]

            # Extract wdt:P1435 (heritage status)
            if "heritageStatusLabel" in result:
                heritage_status_label = result["heritageStatusLabel"]["value"]

            if "startime" in result:
                since_when = result["startime"]["value"]

            if "startime_2" in result:
                since_when_2 = result["startime_2"]["value"]

            if "creatorLabel" in result:
                creator = result["creatorLabel"]["value"]

            if "description" in result:
                description = result["description"]["value"]

        # Update the DataFrame with the extracted data
        data.at[index, "label_"] = label
        data.at[index, "Instance_of"] = instance_of_label
        data.at[index, "Material"] = material_label
        data.at[index, "Heritage_Status"] = heritage_status_label
        data.at[index, "Since"] = since_when
        data.at[index, "Since_2"] = since_when_2
        data.at[index, "Created_by"] = creator
        data.at[index, "Description"] = description

    except Exception as e:
        print(f"Error querying {entity_id}: {e}")

# Filter out metro stops
data = data[data["type"] != "metro_station"]

# %%
import pandas as pd
import re
from SPARQLWrapper import SPARQLWrapper, JSON
import urllib.parse  # For URL encoding

df = data  # Assuming data is your DataFrame

# SPARQL Query function
def get_dbpedia_abstract(label):
    # Remove "Monument to" from the label if it exists
    if label.lower().startswith("monument to "):
        label = label[len("Monument to "):]  # Remove the "Monument to " part

    # Remove parentheses content (e.g., "(some text)")
    label = re.sub(r"\(.*?\)", "", label).strip()

    # Encode the label to be URL-safe
    encoded_label = urllib.parse.quote(label.replace(" ", "_"))

    sparql = SPARQLWrapper("https://dbpedia.org/sparql")

    query = f"""
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX dbr: <http://dbpedia.org/resource/>

    ASK WHERE {{
        dbr:{encoded_label} ?p ?o .
    }}
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    try:
        # Check if resource exists in DBpedia
        results = sparql.query().convert()
        if not results["boolean"]:  # If false, the resource doesn't exist
            return ""

        # If resource exists, fetch the abstract
        query = f"""
        PREFIX dbo: <http://dbpedia.org/ontology/>
        PREFIX dbr: <http://dbpedia.org/resource/>

        SELECT ?abstract WHERE {{
            dbr:{encoded_label} dbo:abstract ?abstract .
            FILTER (lang(?abstract) = 'en')
        }}
        LIMIT 1
        """

        sparql.setQuery(query)
        results = sparql.query().convert()

        if results["results"]["bindings"]:
            return results["results"]["bindings"][0]["abstract"]["value"]
        else:
            return ""

    except Exception as e:
        return f"Error: {str(e)}"

# Apply the function to each row
df["Abstract"] = df["label"].apply(get_dbpedia_abstract)
df
# Out:
# <ipython-input-13-9f0a76c34d9d>:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Abstract"] = df["label"].apply(get_dbpedia_abstract)
#     Itinerary                              Poi_name   role         type  \
# 0           1                   Museo del Novecento  Start       museum
# 1           1  Collections of the Ospedale Maggiore  Stop1       museum
# 2           1                Duomo di Milano Museum  Stop2       museum
# 3           1         Monument to Federico Borromeo  Stop3     monument
# 5           2                   Museo del Novecento  Start       museum
# 6           2                 Pinacoteca Ambrosiana  Stop1  art_gallery
# 7           2          Monument to Giuseppe Missori  Stop2     monument
# 8           2                     San Fedele museum  Stop3       museum
# 10          3                   Museo del Novecento  Start       museum
# 11          3                 Royal Palace of Milan  Stop1       museum
# 12          3         Monument to Federico Borromeo  Stop2     monument
# 13          3            Gallerie d'Italia - Milano  Stop3       museum
#
#     walking_time                                 label   LATITUDE  LONGITUDE  \
# 0              0                   Museo del Novecento  45.463414   9.190261
# 1              9  Collections of the Ospedale Maggiore  45.460009   9.195317
# 2              8                Duomo di Milano Museum  45.463246   9.191625
# 3              8         Monument to Federico Borromeo  45.463196   9.185228
# 5              0                   Museo del Novecento  45.463414   9.190261
# 6              5                 Pinacoteca Ambrosiana  45.463780   9.185952
# 7              5          Monument to Giuseppe Missori  45.461100   9.188100
# 8             10                     San Fedele museum  45.466442   9.191131
# 10             0                   Museo del Novecento  45.463414   9.190261
# 11             2                 Royal Palace of Milan  45.463054   9.191153
# 12             8         Monument to Federico Borromeo  45.463196   9.185228
# 13             8            Gallerie d'Italia - Milano  45.467350   9.190040
#
#       WIKIDATA                                label_     Instance_of Material  \
# 0      Q261233                   Museo del Novecento      art museum     None
# 1    Q17154436  Collections of the Ospedale Maggiore  private museum     None
# 2    Q16337697                Duomo di Milano Museum      art museum     None
# 3   Q115868258         Monument to Federico Borromeo        memorial     None
# 5      Q261233                   Museo del Novecento      art museum     None
# 6     Q1085811                 Pinacoteca Ambrosiana      art museum     None
# 7    Q21141701          Monument to Giuseppe Missori        monument   bronze
# 8    Q24940273                     San Fedele museum  private museum     None
# 10     Q261233                   Museo del Novecento      art museum     None
# 11      Q51105                 Royal Palace of Milan      art museum     None
# 12  Q115868258         Monument to Federico Borromeo        memorial     None
# 13    Q2054135            Gallerie d'Italia - Milano          museum     None
#
#               Heritage_Status Since               Since_2          Created_by  \
# 0   Italian national heritage  None  2010-12-06T00:00:00Z                None
# 1                        None  None  1456-01-01T00:00:00Z                None
# 2                        None  None                  None                None
# 3                        None  None  1865-01-01T00:00:00Z    Costantino Corti
# 5   Italian national heritage  None  2010-12-06T00:00:00Z                None
# 6   Italian national heritage  None  1618-01-01T00:00:00Z                None
# 7                        None  None  1916-01-01T00:00:00Z  Riccardo Ripamonti
# 8                        None  None                  None                None
# 10  Italian national heritage  None  2010-12-06T00:00:00Z                None
# 11  Italian national heritage  None                  None                None
# 12                       None  None  1865-01-01T00:00:00Z    Costantino Corti
# 13  Italian national heritage  None  2011-01-01T00:00:00Z     Salvatore Garau
#
#                                           Description  \
# 0     museum of twentieth-century art in Milan, Italy
# 1                                     museum in Italy
# 2                                     museum in Italy
# 3                                                None
# 5     museum of twentieth-century art in Milan, Italy
# 6                                 art museum in Milan
# 7        statue by Riccardo Ripamonti in Milan, Italy
# 8                                     museum in Italy
# 10    museum of twentieth-century art in Milan, Italy
# 11                                         art museum
# 12                                               None
# 13  art museum in Palazzo della Banca Commerciale ...
#
#                                              Abstract
# 0   The Museo del Novecento ("museum of the twenti...
# 1
# 2
# 3   Federico Borromeo (18 August 1564 – 21 Septemb...
# 5   The Museo del Novecento ("museum of the twenti...
# 6
# 7   Giuseppe Missori (11 June 1829 - 25 March 1911...
# 8
# 10  The Museo del Novecento ("museum of the twenti...
# 11  The Royal Palace of Milan (Italian: Palazzo Re...
# 12  Federico Borromeo (18 August 1564 – 21 Septemb...
# 13

# %%
import pandas as pd
import re
from SPARQLWrapper import SPARQLWrapper, JSON
import urllib.parse  # For URL encoding

df = data  # Assuming data is your DataFrame

# SPARQL Query function
def get_dbpedia_abstract(label):
    # Remove "Monument to" from the label if it exists
    if label.lower().startswith("monument to "):
        label = label[len("Monument to "):]  # Remove the "Monument to " part

    # Remove parentheses content (e.g., "(some text)")
    label = re.sub(r"\(.*?\)", "", label).strip()

    # Encode label safely for DBpedia URI
    encoded_label = urllib.parse.quote(label.replace(" ", "_"))

    sparql = SPARQLWrapper("https://dbpedia.org/sparql")

    # Try direct match first
    query = f"""
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX dbr: <http://dbpedia.org/resource/>

    SELECT ?abstract WHERE {{
        dbr:{encoded_label} dbo:abstract ?abstract .
        FILTER (lang(?abstract) = 'en')
    }}
    LIMIT 1
    """

    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    try:
        results = sparql.query().convert()
        if results["results"]["bindings"]:
            return results["results"]["bindings"][0]["abstract"]["value"]

        # If no direct match, try searching abstracts that contain the label
        # Escape special characters properly inside SPARQL FILTER
        safe_label = label.replace('"', '\\"')  # Escape quotes for SPARQL

        query = f"""
        PREFIX dbo: <http://dbpedia.org/ontology/>

        SELECT ?abstract WHERE {{
            # ?subject dbo:abstract ?abstract .
            FILTER (lang(?abstract) = 'en')
            FILTER (CONTAINS(LCASE(?abstract), LCASE("{safe_label}")))
        }}
        LIMIT 1
        """

        sparql.setQuery(query)
        results = sparql.query().convert()

        if results["results"]["bindings"]:
            return results["results"]["bindings"][0]["abstract"]["value"]
        else:
            return ""

    except Exception as e:
        return f"Error: {str(e)}"

# Apply function to fill empty abstracts
df["Abstract"] = df["label"].apply(get_dbpedia_abstract)
df
# Out:
# <ipython-input-14-8eb09423061d>:69: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Abstract"] = df["label"].apply(get_dbpedia_abstract)
#     Itinerary                              Poi_name   role         type  \
# 0           1                   Museo del Novecento  Start       museum
# 1           1  Collections of the Ospedale Maggiore  Stop1       museum
# 2           1                Duomo di Milano Museum  Stop2       museum
# 3           1         Monument to Federico Borromeo  Stop3     monument
# 5           2                   Museo del Novecento  Start       museum
# 6           2                 Pinacoteca Ambrosiana  Stop1  art_gallery
# 7           2          Monument to Giuseppe Missori  Stop2     monument
# 8           2                     San Fedele museum  Stop3       museum
# 10          3                   Museo del Novecento  Start       museum
# 11          3                 Royal Palace of Milan  Stop1       museum
# 12          3         Monument to Federico Borromeo  Stop2     monument
# 13          3            Gallerie d'Italia - Milano  Stop3       museum
#
#     walking_time                                 label   LATITUDE  LONGITUDE  \
# 0              0                   Museo del Novecento  45.463414   9.190261
# 1              9  Collections of the Ospedale Maggiore  45.460009   9.195317
# 2              8                Duomo di Milano Museum  45.463246   9.191625
# 3              8         Monument to Federico Borromeo  45.463196   9.185228
# 5              0                   Museo del Novecento  45.463414   9.190261
# 6              5                 Pinacoteca Ambrosiana  45.463780   9.185952
# 7              5          Monument to Giuseppe Missori  45.461100   9.188100
# 8             10                     San Fedele museum  45.466442   9.191131
# 10             0                   Museo del Novecento  45.463414   9.190261
# 11             2                 Royal Palace of Milan  45.463054   9.191153
# 12             8         Monument to Federico Borromeo  45.463196   9.185228
# 13             8            Gallerie d'Italia - Milano  45.467350   9.190040
#
#       WIKIDATA                                label_     Instance_of Material  \
# 0      Q261233                   Museo del Novecento      art museum     None
# 1    Q17154436  Collections of the Ospedale Maggiore  private museum     None
# 2    Q16337697                Duomo di Milano Museum      art museum     None
# 3   Q115868258         Monument to Federico Borromeo        memorial     None
# 5      Q261233                   Museo del Novecento      art museum     None
# 6     Q1085811                 Pinacoteca Ambrosiana      art museum     None
# 7    Q21141701          Monument to Giuseppe Missori        monument   bronze
# 8    Q24940273                     San Fedele museum  private museum     None
# 10     Q261233                   Museo del Novecento      art museum     None
# 11      Q51105                 Royal Palace of Milan      art museum     None
# 12  Q115868258         Monument to Federico Borromeo        memorial     None
# 13    Q2054135            Gallerie d'Italia - Milano          museum     None
#
#               Heritage_Status Since               Since_2          Created_by  \
# 0   Italian national heritage  None  2010-12-06T00:00:00Z                None
# 1                        None  None  1456-01-01T00:00:00Z                None
# 2                        None  None                  None                None
# 3                        None  None  1865-01-01T00:00:00Z    Costantino Corti
# 5   Italian national heritage  None  2010-12-06T00:00:00Z                None
# 6   Italian national heritage  None  1618-01-01T00:00:00Z                None
# 7                        None  None  1916-01-01T00:00:00Z  Riccardo Ripamonti
# 8                        None  None                  None                None
# 10  Italian national heritage  None  2010-12-06T00:00:00Z                None
# 11  Italian national heritage  None                  None                None
# 12                       None  None  1865-01-01T00:00:00Z    Costantino Corti
# 13  Italian national heritage  None  2011-01-01T00:00:00Z     Salvatore Garau
#
#                                           Description  \
# 0     museum of twentieth-century art in Milan, Italy
# 1                                     museum in Italy
# 2                                     museum in Italy
# 3                                                None
# 5     museum of twentieth-century art in Milan, Italy
# 6                                 art museum in Milan
# 7        statue by Riccardo Ripamonti in Milan, Italy
# 8                                     museum in Italy
# 10    museum of twentieth-century art in Milan, Italy
# 11                                         art museum
# 12                                               None
# 13  art museum in Palazzo della Banca Commerciale ...
#
#                                              Abstract
# 0   The Museo del Novecento ("museum of the twenti...
# 1
# 2
# 3   Federico Borromeo (18 August 1564 – 21 Septemb...
# 5   The Museo del Novecento ("museum of the twenti...
# 6
# 7   Giuseppe Missori (11 June 1829 - 25 March 1911...
# 8
# 10  The Museo del Novecento ("museum of the twenti...
# 11  The Royal Palace of Milan (Italian: Palazzo Re...
# 12  Federico Borromeo (18 August 1564 – 21 Septemb...
# 13

# %%
df.to_csv(r"/content/gdrive/MyDrive/BICOCCA/TESI/data_for_questions.csv", index=False)

# %%
import pandas as pd
from transformers import AutoModelForCausalLM, AutoTokenizer
import torch

# Model Configuration
MODEL_NAME = "unsloth/mistral-7b-instruct-v0.3-bnb-4bit"
response_list = []
# Function to Initialize Model & Tokenizer
def initialize_model():
    """Load the Llama 2 model and tokenizer."""
    try:
        tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
        model = AutoModelForCausalLM.from_pretrained(
            MODEL_NAME,
            device_map="auto",
            torch_dtype=torch.float16  # Use float16 for efficiency
        )
        return model, tokenizer
    except Exception as e:
        print(f"Error initializing model: {e}")
        return None, None

# Load Model & Tokenizer
model, tokenizer = initialize_model()

# Ensure model is loaded before proceeding
if model is None or tokenizer is None:
    print("Model initialization failed. Exiting.")
    exit()

# Load the dataset
df = pd.read_csv("/content/gdrive/MyDrive/BICOCCA/TESI/data_for_questions.csv")
df = df[df['role']!='Start']

# Handle missing values
df = df.fillna("")

# Iterate over POIs and generate quiz questions & facts
for index, row in df.iterrows():
    label = row["label_"]
    description = row["Description"]

    # Collect available information dynamically
    info_parts = []
    if pd.notna(row["Since_2"]) and row["Since_2"]:
        info_parts.append(f"The {label} was Built/Established around {row['Since_2']}")
    if pd.notna(row["Created_by"]) and row["Created_by"]:
        info_parts.append(f"The Creator/Architect of '{label}' is {row['Created_by']}")
    if pd.notna(row["Material"]) and row["Material"]:
        info_parts.append(f"{label} is made out of {row['Material']}")
    if pd.notna(row["Heritage_Status"]) and row["Heritage_Status"]:
        info_parts.append(f"The Heritage Status of {label} is {row['Heritage_Status']}")
    if pd.notna(row["Abstract"]) and row["Abstract"]:
        info_parts.append(row["Abstract"])  # Abstract is a standalone text

    # Combine the dynamically constructed info section
    info_text = "\n".join(info_parts) if info_parts else "No additional information available."

    # Generate a prompt
    prompt = f"""
You are an expert tour guide in Milan about {label}, {description}.

### TASK:
You must create a Multiple-choice question using the information provided:

Carefully read these information below to generate the question and the answers:
{info_text}

GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
### OUTPUT FORMAT:
Your response must follow this exact structure:
Q: [Write a clear, engaging question about {label} based on above abstract and information]
A) * [Correct answer]
B) [Incorrect answer]
C) [Incorrect answer]
-------------------------------
Fact: [One interesting fact about {label} based on the provided information]

### REQUIREMENTS:
1. Ensure to have a correct answer
2. Create incorrect options.
3. Mark the correct answer with an asterisk *
4. The fact should highlight something notable about {label}.
5. Use the information provided to generate the question and the correct answer
6. Ensure the correct answer is clearly marked.
7. Check that the marked answer is really correct based on the provided knowledge
8. Do not invent answers
9. There must be a correct option in the answers and must be marked *

GENERATE EXACTLY ONE QUESTION
"""

    # Tokenize input
    inputs = tokenizer(prompt, return_tensors="pt").to("cuda")

    # Generate response
    try:
        outputs = model.generate(**inputs, max_new_tokens=2000)
        response = tokenizer.decode(outputs[0], skip_special_tokens=True)
        response_list.append(response)
        print(f"\n--- {label} ---\n{response}")
    except Exception as e:
        print(f"Error generating response for {label}: {e}")
# Out:
# tokenizer_config.json:   0%|          | 0.00/141k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/587k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# model.safetensors:   0%|          | 0.00/4.14G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/157 [00:00<?, ?B/s]
# --- Collections of the Ospedale Maggiore ---
#
# You are an expert tour guide in Milan about Collections of the Ospedale Maggiore, museum in Italy.
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# The Collections of the Ospedale Maggiore was Built/Established around 1456-01-01T00:00:00Z
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Collections of the Ospedale Maggiore based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Collections of the Ospedale Maggiore based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Collections of the Ospedale Maggiore.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
#
# Q: When was the Ospedale Maggiore in Milan established?
# A) 1456-01-01T00:00:00Z *
# B) 1556-01-01T00:00:00Z
# C) 1656-01-01T00:00:00Z
# -------------------------------
# Fact: The Ospedale Maggiore in Milan was established around the year 1456.
#
# --- Duomo di Milano Museum ---
#
# You are an expert tour guide in Milan about Duomo di Milano Museum, museum in Italy.
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# No additional information available.
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Duomo di Milano Museum based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Duomo di Milano Museum based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Duomo di Milano Museum.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
#
# Q: Which of the following is a unique feature of the Duomo di Milano Museum?
# A) * A collection of ancient Roman artifacts
# B) A gallery of modern Italian art
# C) A display of medieval weaponry
# -------------------------------
# Fact: The Duomo di Milano Museum houses a collection of original tools and materials used in the construction of the cathedral.
#
# --- Monument to Federico Borromeo ---
#
# You are an expert tour guide in Milan about Monument to Federico Borromeo, .
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# The Monument to Federico Borromeo was Built/Established around 1865-01-01T00:00:00Z
# The Creator/Architect of 'Monument to Federico Borromeo' is Costantino Corti
# Federico Borromeo (18 August 1564 – 21 September 1631) was an Italian cardinal and Archbishop of Milan.
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Monument to Federico Borromeo based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Monument to Federico Borromeo based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Monument to Federico Borromeo.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
# Q: Who was the architect of the Monument to Federico Borromeo?
# A) * Costantino Corti
# B) Leonardo da Vinci
# C) Michelangelo
# -------------------------------
# Fact: The Monument to Federico Borromeo was built around 1865.
#
# --- Pinacoteca Ambrosiana ---
#
# You are an expert tour guide in Milan about Pinacoteca Ambrosiana, art museum in Milan.
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# The Pinacoteca Ambrosiana was Built/Established around 1618-01-01T00:00:00Z
# The Heritage Status of Pinacoteca Ambrosiana is Italian national heritage
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Pinacoteca Ambrosiana based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Pinacoteca Ambrosiana based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Pinacoteca Ambrosiana.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
#
# Q: When was the Pinacoteca Ambrosiana established?
# A) * 1618
# B) 1500
# C) 1700
# -------------------------------
# Fact: The Pinacoteca Ambrosiana is an Italian national heritage.
#
# --- Monument to Giuseppe Missori ---
#
# You are an expert tour guide in Milan about Monument to Giuseppe Missori, statue by Riccardo Ripamonti in Milan, Italy.
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# The Monument to Giuseppe Missori was Built/Established around 1916-01-01T00:00:00Z
# The Creator/Architect of 'Monument to Giuseppe Missori' is Riccardo Ripamonti
# Monument to Giuseppe Missori is made out of bronze
# Giuseppe Missori (11 June 1829 - 25 March 1911) was an Italian patriot, military leader during the Italian unification, and politician. He served under Garibaldi during the Second Italian War of Independence, the Expedition of the Thousand, and the Third Italian War of Independence. After the unification of Italy, he was twice a member of the City Council of Milan.
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Monument to Giuseppe Missori based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Monument to Giuseppe Missori based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Monument to Giuseppe Missori.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
# Q: Who was the creator of the Monument to Giuseppe Missori?
# A) * Riccardo Ripamonti
# B) Giuseppe Missori
# C) Leonardo da Vinci
# -------------------------------
# Fact: The Monument to Giuseppe Missori was built around 1916 and is made out of bronze.
#
# --- San Fedele museum ---
#
# You are an expert tour guide in Milan about San Fedele museum, museum in Italy.
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# No additional information available.
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about San Fedele museum based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about San Fedele museum based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about San Fedele museum.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
#
# Q: Which museum in Milan is known for its collection of medieval and Renaissance art?
# A) * San Fedele museum
# B) Milan Cathedral museum
# C) Sforza Castle museum
# -------------------------------
# Fact: San Fedele museum houses a significant collection of medieval and Renaissance art.
#
# --- Royal Palace of Milan ---
#
# You are an expert tour guide in Milan about Royal Palace of Milan, art museum.
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# The Heritage Status of Royal Palace of Milan is Italian national heritage
# The Royal Palace of Milan (Italian: Palazzo Reale di Milano) was the seat of government in the Italian city of Milan for many centuries. Today, it serves as a cultural centre and it is home to international art exhibitions. It spans through an area of 7,000 square meters and it regularly hosts modern and contemporary art works and famous collections in cooperation with notable museums and cultural institutions from across the world. More than 1,500 masterpieces are on display annually. It was originally designed to include two courtyards but these were later dismantled to make room for the Duomo. The Palazzo is located to the right of the Duomo's facade, opposite to Galleria Vittorio Emanuele II. The facade of the Palazzo creates a recess in Piazza del Duomo which functions as a courtyard, known as the Piazzetta Reale (literally, a "Small Royal Square"). The famous Hall of Caryatids can be found on the main floor of the building, heavily damaged by World War II's air raids.After the war the Palazzo remained abandoned for over two years and its condition further deteriorated. Many of the Palazzo's neoclassical interiors were lost in this period.
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Royal Palace of Milan based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Royal Palace of Milan based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Royal Palace of Milan.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
#
# Q: Which of the following is true about the Royal Palace of Milan?
# A) * It is a cultural centre and home to international art exhibitions.
# B) It was originally designed to include two courtyards but these were later dismantled to make room for the Duomo.
# C) It was abandoned for over two years after World War II and its condition further deteriorated.
# -------------------------------
# Fact: More than 1,500 masterpieces are on display annually at the Royal Palace of Milan.
#
# --- Monument to Federico Borromeo ---
#
# You are an expert tour guide in Milan about Monument to Federico Borromeo, .
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# The Monument to Federico Borromeo was Built/Established around 1865-01-01T00:00:00Z
# The Creator/Architect of 'Monument to Federico Borromeo' is Costantino Corti
# Federico Borromeo (18 August 1564 – 21 September 1631) was an Italian cardinal and Archbishop of Milan.
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Monument to Federico Borromeo based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Monument to Federico Borromeo based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Monument to Federico Borromeo.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
# Q: Who was the architect of the Monument to Federico Borromeo?
# A) * Costantino Corti
# B) Leonardo da Vinci
# C) Michelangelo
# -------------------------------
# Fact: The Monument to Federico Borromeo was built around 1865.
#
# --- Gallerie d'Italia - Milano ---
#
# You are an expert tour guide in Milan about Gallerie d'Italia - Milano, art museum in Palazzo della Banca Commerciale Italiana, Milan, Italy.
#
# ### TASK:
# You must create a Multiple-choice question using the information provided:
#
# Carefully read these information below to generate the question and the answers:
# The Gallerie d'Italia - Milano was Built/Established around 2011-01-01T00:00:00Z
# The Creator/Architect of 'Gallerie d'Italia - Milano' is Salvatore Garau
# The Heritage Status of Gallerie d'Italia - Milano is Italian national heritage
#
# GENERATE THE QUESTION AND THE ANSWER BASED ONLY ON THE PROVIDED INFORMATION.
# ### OUTPUT FORMAT:
# Your response must follow this exact structure:
# Q: [Write a clear, engaging question about Gallerie d'Italia - Milano based on above abstract and information]
# A) * [Correct answer]
# B) [Incorrect answer]
# C) [Incorrect answer]
# -------------------------------
# Fact: [One interesting fact about Gallerie d'Italia - Milano based on the provided information]
#
# ### REQUIREMENTS:
# 1. Ensure to have a correct answer
# 2. Create incorrect options.
# 3. Mark the correct answer with an asterisk *
# 4. The fact should highlight something notable about Gallerie d'Italia - Milano.
# 5. Use the information provided to generate the question and the correct answer
# 6. Ensure the correct answer is clearly marked.
# 7. Check that the marked answer is really correct based on the provided knowledge
# 8. Do not invent answers
# 9. There must be a correct option in the answers and must be marked *
#
# GENERATE EXACTLY ONE QUESTION
# Q: Who was the architect of Gallerie d'Italia - Milano?
# A) * Salvatore Garau
# B) Leonardo da Vinci
# C) Michelangelo
# -------------------------------
# Fact: Gallerie d'Italia - Milano was established in 2011 and holds Italian national heritage status.

# %%
def extract_poi_info(text):
    # Extract POI name (stop at the first comma)
    poi_start = text.find('about ') + 6
    poi_end = text.find(',', poi_start)
    if poi_end == -1:  # If no comma found, use the end of the line
        poi_end = text.find('\n', poi_start)
    poi_name = text[poi_start:poi_end].strip()

    # Find the section after 'GENERATE EXACTLY ONE QUESTION'
    question_section = text.split('GENERATE EXACTLY ONE QUESTION')[-1].strip()

    # Extract question
    question_start = question_section.find('Q: ') + 3
    question_end = question_section.find('\n', question_start)
    question = question_section[question_start:question_end].strip()

    # Extract answers
    answers = []
    answer_lines = question_section.split('\n')[1:4]
    for line in answer_lines:
        answers.append(line.strip())

    # Extract fact
    fact_start = question_section.find('Fact: ') + 6
    fact = question_section[fact_start:].strip()

    return {
        'poi_name': poi_name,
        'question': question,
        'answers': answers,
        'fact': fact
    }

def process_poi_list(text_list):
    """
    Process a list of POI texts and return a list of extracted information.

    Args:
    text_list (list): A list of texts about different POIs

    Returns:
    list: A list of dictionaries, each containing extracted POI information
    """
    processed_pois = []

    for text in text_list:
        try:
            poi_info = extract_poi_info(text)
            processed_pois.append(poi_info)
        except Exception as e:
            print(f"Error processing text: {e}")
            # Optionally, you can append a placeholder or skip the problematic text
            processed_pois.append({
                'poi_name': 'Error',
                'question': 'Error',
                'answers': [],
                'fact': 'Error processing text'
            })

    return processed_pois

# Example usage
# Assuming your_list is the list of texts
processed_pois = process_poi_list(response_list)

# To print out all extracted information
# for poi in processed_pois:
#     print("POI Name:", poi['poi_name'])
#     print("Question:", poi['question'])
#     print("Answers:", poi['answers'])
#     print("Fact:", poi['fact'])
#     print("---")

# %%
processed_pois
# Out:
# [{'poi_name': 'Collections of the Ospedale Maggiore',
#   'question': 'When was the Ospedale Maggiore in Milan established?',
#   'answers': ['A) 1456-01-01T00:00:00Z *',
#    'B) 1556-01-01T00:00:00Z',
#    'C) 1656-01-01T00:00:00Z'],
#   'fact': 'The Ospedale Maggiore in Milan was established around the year 1456.'},
#  {'poi_name': 'Duomo di Milano Museum',
#   'question': 'Which of the following is a unique feature of the Duomo di Milano Museum?',
#   'answers': ['A) * A collection of ancient Roman artifacts',
#    'B) A gallery of modern Italian art',
#    'C) A display of medieval weaponry'],
#   'fact': 'The Duomo di Milano Museum houses a collection of original tools and materials used in the construction of the cathedral.'},
#  {'poi_name': 'Monument to Federico Borromeo',
#   'question': 'Who was the architect of the Monument to Federico Borromeo?',
#   'answers': ['A) * Costantino Corti',
#    'B) Leonardo da Vinci',
#    'C) Michelangelo'],
#   'fact': 'The Monument to Federico Borromeo was built around 1865.'},
#  {'poi_name': 'Pinacoteca Ambrosiana',
#   'question': 'When was the Pinacoteca Ambrosiana established?',
#   'answers': ['A) * 1618', 'B) 1500', 'C) 1700'],
#   'fact': 'The Pinacoteca Ambrosiana is an Italian national heritage.'},
#  {'poi_name': 'Monument to Giuseppe Missori',
#   'question': 'Who was the creator of the Monument to Giuseppe Missori?',
#   'answers': ['A) * Riccardo Ripamonti',
#    'B) Giuseppe Missori',
#    'C) Leonardo da Vinci'],
#   'fact': 'The Monument to Giuseppe Missori was built around 1916 and is made out of bronze.'},
#  {'poi_name': 'San Fedele museum',
#   'question': 'Which museum in Milan is known for its collection of medieval and Renaissance art?',
#   'answers': ['A) * San Fedele museum',
#    'B) Milan Cathedral museum',
#    'C) Sforza Castle museum'],
#   'fact': 'San Fedele museum houses a significant collection of medieval and Renaissance art.'},
#  {'poi_name': 'Royal Palace of Milan',
#   'question': 'Which of the following is true about the Royal Palace of Milan?',
#   'answers': ['A) * It is a cultural centre and home to international art exhibitions.',
#    'B) It was originally designed to include two courtyards but these were later dismantled to make room for the Duomo.',
#    'C) It was abandoned for over two years after World War II and its condition further deteriorated.'],
#   'fact': 'More than 1,500 masterpieces are on display annually at the Royal Palace of Milan.'},
#  {'poi_name': 'Monument to Federico Borromeo',
#   'question': 'Who was the architect of the Monument to Federico Borromeo?',
#   'answers': ['A) * Costantino Corti',
#    'B) Leonardo da Vinci',
#    'C) Michelangelo'],
#   'fact': 'The Monument to Federico Borromeo was built around 1865.'},
#  {'poi_name': "Gallerie d'Italia - Milano",
#   'question': "Who was the architect of Gallerie d'Italia - Milano?",
#   'answers': ['A) * Salvatore Garau',
#    'B) Leonardo da Vinci',
#    'C) Michelangelo'],
#   'fact': "Gallerie d'Italia - Milano was established in 2011 and holds Italian national heritage status."}]
